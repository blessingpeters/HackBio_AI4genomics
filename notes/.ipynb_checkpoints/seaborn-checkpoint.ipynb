# %%
pip install seaborn;
# Out:
# Requirement already satisfied: seaborn in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/blessing/Desktop/HackBio-internship/hackbio/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sns.set_theme(style='whitegrid')
print('Seaborn imported successfully')
# Out:
# Seaborn imported successfully

# %%
df = pd.DataFrame({
    'Gene': ['GeneA', 'GeneA', 'GeneB', 'GeneB', 'GeneC', 'GeneC', 'GeneD', 'GeneD'],
    'Condition': ['Control', 'Treatment'] * 4,
    'Expression': [5.2, 6.1, 2.1, 3.3, 7.8, 5.9, 4.4, 6.0],
    'Replicate': [1, 1, 1, 1, 1, 1, 1, 1]
})

df
# Out:
#     Gene  Condition  Expression  Replicate
# 0  GeneA    Control         5.2          1
# 1  GeneA  Treatment         6.1          1
# 2  GeneB    Control         2.1          1
# 3  GeneB  Treatment         3.3          1
# 4  GeneC    Control         7.8          1
# 5  GeneC  Treatment         5.9          1
# 6  GeneD    Control         4.4          1
# 7  GeneD  Treatment         6.0          1

# %% [markdown]
# Distribution plots

# %% [markdown]
# 3.1 Histogram with histoplots()

# %%
sns.histplot(data=df, x='Expression', bins=6)
plt.title('Distribution of Expression Values')
plt.show()

# %% [markdown]
# 3.2 Smoothed density with kdeplot()

# %%
sns.kdeplot(data=df, x='Expression', fill=True)
plt.title('Density of Expression Values')
plt.show()

# %% [markdown]
# 3.3 Compare distributions by group with displot()

# %%
sns.displot(data=df, x='Expression', hue='Condition', kind='hist', bins=5)
plt.show()

# %%
bacteria_path = './bacteria.csv'

# %%
bacteria = pd.read_csv(bacteria_path)

# %%
bacteria.head()
# Out:
#          C1        C2 sample_id           species Isolation origin  \
# 0  7.895415  6.303232      A001  Escherichia coli            urine
# 1  2.833671  6.823800      A002  Escherichia coli            blood
# 2  3.178256  5.519982      A003  Escherichia coli            blood
# 3  5.030077  4.642758      A004  Escherichia coli            feces
# 4  2.691040  4.057780      A005  Escherichia coli            feces
#
#            Phenotype  BSL      soln  carb_fit  cipro_fit  genta_fit   kan_fit  \
# 0  Pathogenic strain    2  0.043922  0.833539   0.040470   0.429654  0.046829
# 1  Pathogenic strain    2  0.098481  0.964883   0.110471   0.233285  0.000000
# 2   Commensal strain    1  0.066501  0.498872   0.061445   0.564547  0.313546
# 3  Pathogenic strain    2  0.116999  1.080682   0.101199   0.655379  0.305054
# 4   Commensal strain    1  0.101523  0.272807   0.120601   0.186437  0.121745
#
#     pip_fit  labels
# 0  0.857467       1
# 1  1.403835       6
# 2  0.368546       8
# 3  1.441512       0
# 4  0.398072       3

# %%
bacteria.shape
# Out:
# (50, 14)

# %% [markdown]
# A histogram of carb_fit

# %%
sns.histplot(data=bacteria, x="carb_fit", bins=10)
plt.title("A histogram of carb_fit")
plt.show()

# %% [markdown]
# A KDE plot of cipro_fit

# %%
sns.kdeplot(data=bacteria, x='cipro_fit', fill=True)
plt.title("A KDE plot of cipro_fit")
plt.show()

# %% [markdown]
# A displot() grouped by Phenotype

# %%
sns.displot(data=bacteria, x='carb_fit', hue='Phenotype', kind='hist', bins=10)
plt.title("A displot() grouped by Phenotype")
plt.show()

# %% [markdown]
# Scatter and Relationship Plots
# Use these when you want to study relationships between variables.

# %%
growth = pd.DataFrame({
    'Time': [0, 2, 4, 6, 8, 0, 2, 4, 6, 8],
    'OD600': [0.05, 0.12, 0.24, 0.41, 0.60, 0.05, 0.15, 0.31, 0.52, 0.73],
    'Condition': ['Control'] * 5 + ['Treatment'] * 5
})

growth
# Out:
#    Time  OD600  Condition
# 0     0   0.05    Control
# 1     2   0.12    Control
# 2     4   0.24    Control
# 3     6   0.41    Control
# 4     8   0.60    Control
# 5     0   0.05  Treatment
# 6     2   0.15  Treatment
# 7     4   0.31  Treatment
# 8     6   0.52  Treatment
# 9     8   0.73  Treatment

# %%
sns.scatterplot(data=growth, x='Time', y='OD600', hue='Condition')
plt.title('Growth Measurements')
plt.show()

# %%
sns.lineplot(data=growth, x='Time', y='OD600', hue='Condition', marker='o')
plt.title('Growth Curve')
plt.show()

# %%
sns.relplot(data=growth, x='Time', y='OD600', hue='Condition', kind='scatter')
plt.show()
